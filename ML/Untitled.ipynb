# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

# %%
cancer_data = load_breast_cancer()

# %%
X_train, X_test, y_train, y_test = train_test_split(cancer_data['data'], cancer_data['target'],stratify=cancer_data['target'], test_size=0.4, random_state=42)

# %%
randomforest = RandomForestClassifier(random_state=42)
randomforest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
accuracy = randomforest.score(X_test, y_test)

# %%
print(f'랜덤 포레스 정확도: {accuracy:.3f}')
# Out:
# 랜덤 포레스 정확도: 0.939

# %% [markdown]
# ### 하이퍼파라미터

# %%
param_bounds = {'x':(-1, 5),
                'y':(0, 4)} #x범위를 -1에 5사이 탐색하겠다는 뜻

# %%
def eval_function(x, y):
     return -x **2 - (y-2) **2 + 10

# %%
from bayes_opt import BayesianOptimization

# %%
optimizer = BayesianOptimization(f=eval_function,
                                 pbounds=param_bounds,
                                 random_state=0)

# %%
optimizer.maximize(init_points=2, n_iter=10)
# Out:
# |   iter    |  target   |     x     |     y     |
# -------------------------------------------------
# | 13        | 7.282     | 1.542     | 2.584     |
# | 14        | 4.902     | 1.626     | 3.567     |
# | 15        | 9.965     | -0.1683   | 1.918     |
# | 16        | 9.754     | 0.4951    | 1.97      |
# | 17        | 9.801     | -0.3238   | 2.307     |
# | 18        | 9.996     | 0.05443   | 2.038     |
# | 19        | 9.961     | 0.05686   | 1.81      |
# | 20        | 9.996     | -0.05645  | 2.031     |
# | 21        | 9.998     | -0.005553 | 1.958     |
# | 22        | 9.993     | -0.004069 | 2.086     |
# | 23        | 10.0      | 0.003473  | 1.985     |
# | 24        | 9.999     | -0.01782  | 1.967     |
# ...

# %%
optimizer.max #평가점수 최대일 때 타깃, x, y값 출력
# Out:
# {'target': 9.999755089307419,
#  'params': {'x': 0.003472987507663623, 'y': 1.9847406077987262}}

# %%
###자건거

# %%
###자건거

# %%
import os
print(os.getcwd())
# Out:
# /Users/suhyeon/ML

# %%
import numpy as np
import pandas as pd # 판다스 임포트

# 데이터 경로
data_path = '/Users/suhyeon/ML/bike-sharing-demand/'

train = pd.read_csv(data_path + 'train.csv') # 훈련 데이터
test = pd.read_csv(data_path + 'test.csv')   # 테스트 데이터
submission = pd.read_csv(data_path + 'sampleSubmission.csv') # 제출 샘플 데이터

# %%
train.shape, test.shape
# Out:
# ((10886, 12), (6493, 9))

# %%
train.head
# Out:
# <bound method NDFrame.head of                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
submission.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
print(train['datetime'][100])
print(train['datetime'][100].split())
print(train['datetime'][100].split[0])
print(train['datetime'][100].split()[1])
# Out:
# 2011-01-05 09:00:00
# ['2011-01-05', '09:00:00']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 print(train['datetime'][100])
#       2 print(train['datetime'][100].split())
# ----> 3 print(train['datetime'][100].split[0])
#       4 print(train['datetime'][100].split()[1])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
print(train['datetime'][100].split()[0])
print(train['datetime'][100].split()[0].split("-"))
print(train['datetime'][100].split()[0].split("-")[0])
print(train['datetime'][100].split()[0].split("-")[1])
print(train['datetime'][100].split()[0].split("-")[2])
# Out:
# 2011-01-05
# ['2011', '01', '05']
# 2011
# 01
# 05

# %%
print(train['datetime'][100].split()[1])
print(train['datetime'][100].split()[1].split(":"))
print(train['datetime'][100].split()[1].split(":")[0])
print(train['datetime'][100].split()[1].split(":")[1])
print(train['datetime'][100].split()[1].split(":")[2])
# Out:
# 09:00:00
# ['09', '00', '00']
# 09
# 00
# 00

# %%
train['date'] = train['datetime'].apply(lambda x: x.split()[0])

train['year'] = train['datetime'].apply(lambda x: x.split()[0].split('-')[0])
train['month'] = train['datetime'].apply(lambda x: x.split()[0].split('-')[1])
train['day'] = train['datetime'].apply(lambda x: x.split()[0].split('-')[2])
train['hour'] = train['datetime'].apply(lambda x: x.split()[1].split(':')[0])
train['minute'] = train['datetime'].apply(lambda x: x.split()[1].split(':')[1])
train['second'] = train['datetime'].apply(lambda x: x.split()[1].split(':')[2])

train['year'] = train['datetime'].apply(lambda x: x.split()[0].split('-')[0])

# %%
from datetime import datetime
import calendar

print(train['date'][100])
print(datetime.strptime(train['date'][100], '%Y-%m-%d'))

print(datetime.strptime(train['date'][100], '%Y-%m-%d').weekday())
print(calendar.day_name[datetime.strptime(train['date'][100], '%Y-%m-%d').weekday()])
# Out:
# 2011-01-05
# 2011-01-05 00:00:00
# 2
# Wednesday

# %%
train['weekday'] = train['date'].apply(lambda datString:
                                       calendar.day_name[datetime.strptime(dateString, "%Y-%m-%d").weekday()])

# %%
train['season'] = train['season'].map({1: 'Spring',
                                       2: 'Summer',
                                       3: 'Fall',
                                       4: 'Winter' })
train['weather'] = train['weather'].map({1: 'Clear', 
                                         2: 'Mist, Few clouds', 
                                         3: 'Light Snow, Rain, Thunderstorm',
                                         4: 'Heavy Rain, Thunderstorm, Snow, Fog'})

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday weather  temp   atemp  \
# 0  2011-01-01 00:00:00  Spring        0           0   Clear  9.84  14.395
# 1  2011-01-01 01:00:00  Spring        0           0   Clear  9.02  13.635
# 2  2011-01-01 02:00:00  Spring        0           0   Clear  9.02  13.635
# 3  2011-01-01 03:00:00  Spring        0           0   Clear  9.84  14.395
# 4  2011-01-01 04:00:00  Spring        0           0   Clear  9.84  14.395
#
#    humidity  windspeed  casual  registered  count        date  year month day  \
# 0        81        0.0       3          13     16  2011-01-01  2011    01  01
# 1        80        0.0       8          32     40  2011-01-01  2011    01  01
# 2        80        0.0       5          27     32  2011-01-01  2011    01  01
# 3        75        0.0       3          10     13  2011-01-01  2011    01  01
# 4        75        0.0       0           1      1  2011-01-01  2011    01  01
#
#   hour minute second
# 0   00     00     00
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# 폰트 크기 설정
mpl.rc('font', size=15)

# 히스토그램 시각화
sns.histplot(train['count'], bins=15)
plt.show()

# %%
mpl.rc('font', size=14)
mpl.rc('axes', titlesize=15)
figure, axes = plt.subplots(nrows=3, ncols=2)
plt.tight_layout()
figure.set_size_inches(10, 9)

sns.barplot(x='year', y='count', data=train, ax=axes[0, 0])
sns.barplot(x='month', y='count', data=train, ax=axes[0, 1])
sns.barplot(x='day', y='count', data=train, ax=axes[1, 0])
sns.barplot(x='hour', y='count', data=train, ax=axes[1, 1])
sns.barplot(x='minute', y='count', data=train, ax=axes[2, 0])
sns.barplot(x='second', y='count', data=train, ax=axes[2, 1])

axes[0, 0].set(title='Rental amounts by year')
axes[0, 1].set(title='Rental amounts by month')
axes[1, 0].set(title='Rental amounts by day')
axes[1, 1].set(title='Rental amounts by hour')
axes[2, 0].set(title='Rental amounts by minute')
axes[2, 1].set(title='Rental amounts by second')

axes[1, 0].tick_params(axis='x', labelrotation=90)
axes[1, 1].tick_params(axis='x', labelrotation=90)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 2x2 서브플롯 생성
figure, axes = plt.subplots(nrows=2, ncols=2)  # ✅ 변수 이름 수정
plt.tight_layout()
figure.set_size_inches(10, 10)

# Boxplot 그리기 (올바른 방식으로 ax 설정)
sns.boxplot(x='season', y='count', data=train, ax=axes[0, 0])  # ✅ ax=axes[0, 0]
sns.boxplot(x='weather', y='count', data=train, ax=axes[0, 1])  # ✅ ax=axes[0, 1]
sns.boxplot(x='holiday', y='count', data=train, ax=axes[1, 0])  # ✅ ax=axes[1, 0]
sns.boxplot(x='workingday', y='count', data=train, ax=axes[1, 1])  # ✅ ax=axes[1, 1]

# 제목 설정
axes[0, 0].set(title='Box Plot On Count Across Season')
axes[0, 1].set(title='Box Plot On Count Across Weather')
axes[1, 0].set(title='Box Plot On Count Across Holiday')
axes[1, 1].set(title='Box Plot On Count Across Working Day')

# x축 레이블 회전
axes[0, 1].tick_params(axis='x', labelrotation=10)

plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

mpl.rc('font', size=11)  # ✅ 폰트 크기 설정

# ✅ ncols=1 추가하여 1열짜리 서브플롯 생성
figure, axes = plt.subplots(nrows=5, ncols=1, figsize=(12, 18))  

# ✅ pointplot 그리기 (axes 배열이 1차원이므로 axes[i]로 접근)
sns.pointplot(x='hour', y='count', data=train, hue='workingday', ax=axes[0])
sns.pointplot(x='hour', y='count', data=train, hue='holiday', ax=axes[1])
sns.pointplot(x='hour', y='count', data=train, hue='weekday', ax=axes[2])
sns.pointplot(x='hour', y='count', data=train, hue='season', ax=axes[3])
sns.pointplot(x='hour', y='count', data=train, hue='weather', ax=axes[4])

plt.tight_layout()  # ✅ 레이아웃 조정
plt.show()  # ✅ 그래프 출력

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

mpl.rc('font', size=15)  # 폰트 크기 설정

# ✅ 2x2 Figure 생성
figure, axes = plt.subplots(nrows=2, ncols=2, figsize=(7, 6))  

# ✅ regplot 그래프 그리기
sns.regplot(x='temp', y='count', data=train, ax=axes[0, 0],
            scatter_kws={'alpha': 0.2}, line_kws={'color': 'blue'})

sns.regplot(x='atemp', y='count', data=train, ax=axes[0, 1],
            scatter_kws={'alpha': 0.2}, line_kws={'color': 'blue'})

sns.regplot(x='windspeed', y='count', data=train, ax=axes[1, 0],
            scatter_kws={'alpha': 0.2}, line_kws={'color': 'blue'})

sns.regplot(x='humidity', y='count', data=train, ax=axes[1, 1],
            scatter_kws={'alpha': 0.2}, line_kws={'color': 'blue'})

plt.tight_layout()  # ✅ 그래프 간격 자동 조정
plt.show()  # ✅ 그래프 출력

# %%
train[['temp', 'atemp', 'humidity', 'windspeed', 'count']].corr()
# Out:
#                temp     atemp  humidity  windspeed     count
# temp       1.000000  0.984945 -0.064783  -0.017973  0.394476
# atemp      0.984945  1.000000 -0.043376  -0.057591  0.389802
# humidity  -0.064783 -0.043376  1.000000  -0.318544 -0.317377
# windspeed -0.017973 -0.057591 -0.318544   1.000000  0.101361
# count      0.394476  0.389802 -0.317377   0.101361  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corrMat = train[['temp', 'atemp', 'humidity', 'windspeed', 'count']].corr()
fig, ax = plt.subplots(figsize=(6, 5))
sns.heatmap(corrMat, annot=True, fmt=".2f", cmap="coolwarm", ax=ax)
plt.title('Heatmap of Numerical Data')
plt.show()

# %%
import pandas as pd 

data_path = '/Users/suhyeon/ML/bike-sharing-demand/'

train = pd.read_csv(data_path + 'train.csv') # 훈련 데이터
test = pd.read_csv(data_path + 'test.csv')   # 테스트 데이터
submission = pd.read_csv(data_path + 'sampleSubmission.csv') # 제출 샘플 데이터

# %%
train = train[train['weather'] != 4]
all_data = pd.concat([train, test], ignore_index=True)
all_data

# %%
from datetime import datetime
# 날짜 피처 생성

all_data['date'] = all_data['datetime'].apply(lambda x: x.split()[0])
# 연도 피처 생성
all_data['year'] = all_data['datetime'].apply(lambda x: x.split()[0].split('-')[0])
# 월 피처 생성
all_data['month'] = all_data['datetime'].apply(lambda x: x.split()[0].split('-')[1])
# 시 피처 생성
all_data['hour'] = all_data['datetime'].apply(lambda x: x.split()[1].split(':')[0])
# 요일 피처 생성
all_data['weekday'] = all_data['date'].apply(lambda dateString : datetime.strptime(dateString, "%Y-%m-%d").weekday())

# %%
drop_features = ['casual', 'registered', 'datetime', 'date', 'month', 'windspeed']
all_data = all_data.drop(drop_features, axis=1)

# %%
X_train = all_data[~pd.isnull(all_data['count'])]
X_test = all_data[pd.isnull(all_data['count'])]

X_train = X_train.drop(['count'], axis=1)
X_test = X_test.drop(['count'], axis=1)

y = train['count']
X_train.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  year hour  \
# 0       1        0           0        1  9.84  14.395        81  2011   00
# 1       1        0           0        1  9.02  13.635        80  2011   01
# 2       1        0           0        1  9.02  13.635        80  2011   02
# 3       1        0           0        1  9.84  14.395        75  2011   03
# 4       1        0           0        1  9.84  14.395        75  2011   04
#
#    weekday
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5

# %%
import numpy as np

def rmsle(y_true, y_pred, convertExp=True):
    if convertExp:
        y_true = np.exp(y_true)
        y_pred = np.exp(y_pred)

    log_true = np.nan_to_num(np.log(y_true + 1))
    log_pred = np.nan_to_num(np.log(y_pred + 1))

    output = np.sqrt(np.mean((log_true - log_pred) ** 2))
    return output

# %%
from sklearn.linear_model import LinearRegression
linear_reg_model = LinearRegression()

# %%
log_y = np.log(y)
linear_reg_model.fit(X_train, log_y)

# %%
preds = linear_reg_model.predict(X_train)  # Model predictions
rmsle_value = rmsle(log_y, preds, True)  # Compute RMSLE
print(f'선형 회귀의 RMSLE 값 : {rmsle_value:.4f}')froe sklearn. linear_nodel import Ridge
fron sklearn.nodel_selection import GridSearchCv
froa sklearn inport netrics
ridge_nodel = Ridge)

# %%
from sklearn.linear_nodel import Ridge
from sklearn.nodel_selection import GridSearchCv
from sklearn import netrics

ridge_nodel = Ridge()

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

ridge_model = Ridge()

ridge_params = {
    'max_iter': [3000], 
    'alpha': [0.1, 1, 2, 3, 4, 10, 30, 200, 300, 400, 800, 900, 1000]
}

# Define RMSLE scorer
rmsle_scorer = metrics.make_scorer(rmsle, greater_is_better=False)

# Perform Grid Search
gridsearch_ridge_model = GridSearchCV(
    estimator=ridge_model,
    param_grid=ridge_params,
    scoring=rmsle_scorer,
    cv=5
)

# %%
log_y = np.log(y)
gridsearch_ridge_model.fit(X_train, log_y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 2, 3, 4, 10, 30, 200, 300, 400, 800,
#                                    900, 1000],
#                          'max_iter': [3000]},
#              scoring=make_scorer(rmsle, greater_is_better=False, response_method='predict'))

# %%
print('최적 하이퍼파라미터 :', gridsearch_ridge_model.best_params_)
# Out:
# 최적 하이퍼파라미터 : {'alpha': 0.1, 'max_iter': 3000}

# %%
preds = gridsearch_ridge_model.best_estimator_.predict(X_train)

print(f'릿지 회귀 RMSLE 값 : {rmsle(log_y, preds, True):.4f}')
# Out:
# 릿지 회귀 RMSLE 값 : 1.0205

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import numpy as np

lasso_model = Lasso()

lasso_alpha = 1 / np.array([0.1, 1, 2, 3, 4, 10, 30, 100, 200, 300, 400, 800, 900, 1000])
lasso_params = {'max_iter': [3000], 'alpha': lasso_alpha}

rmsle_scorer = metrics.make_scorer(rmsle, greater_is_better=False)

gridsearch_lasso_model = GridSearchCV(
    estimator=lasso_model,
    param_grid=lasso_params,
    scoring=rmsle_scorer,
    cv=5
)

log_y = np.log(y)

gridsearch_lasso_model.fit(X_train, log_y)

print('최적 하이퍼파라미터 :', gridsearch_lasso_model.best_params_)
# Out:
# 최적 하이퍼파라미터 : {'alpha': 0.00125, 'max_iter': 3000}

# %%
preds = gridsearch_lasso_model.best_estimator_.predict(X_train)
print(f'라 회귀 RMSLE 값 : {rmsle(log_y, preds, True):.4f}')
# Out:
# 라 회귀 RMSLE 값 : 1.0205

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
randomforest_model = RandomForestRegressor()

rf_params = {'random_state':[42], 'n_estimators': [100, 120, 140]}
gridsearch_random_forest_model =  GridSearchCV(estimator=randomforest_model,
                                               param_grid=rf_params,
                                               scoring=rmsle_scorer,
                                               cv = 5)
log_y = np.log(y)
gridsearch_random_forest_model.fit(X_train, log_y)
print('최적 하이퍼파라미터 :', gridsearch_random_forest_model.best_params_)
# Out:
# 최적 하이퍼파라미터 : {'n_estimators': 140, 'random_state': 42}

# %%
preds = gridsearch_random_forest_model.best_estimator_.predict(X_train)
print(f'랜덤 포레스 회귀 RMSLE 값 : {rmsle(log_y, preds, True):.4f}')
# Out:
# 랜덤 포레스 회귀 RMSLE 값 : 0.1127

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'gridsearch_random_forest_model' is a trained model
random_forest_preds = gridsearch_random_forest_model.best_estimator_.predict(X_test)

# Create subplots
figure, axes = plt.subplots(ncols=2)
figure.set_size_inches(10, 4)

# Plot training data distribution
sns.histplot(y, bins=50, ax=axes[0])
axes[0].set_title('Train Data Distribution')

# Plot predicted test data distribution
sns.histplot(np.exp(random_forest_preds), bins=50, ax=axes[1])
axes[1].set_title('Predicted Test Data Distribution')

plt.show()
